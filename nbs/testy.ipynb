# %%
import datasets
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import datasets
#       2 import os
#
# ModuleNotFoundError: No module named 'datasets'

# %%
ds_subset = datasets.load_from_disk(os.path.join('..', 'data', 'wikiart_filtered_remapped_FINAL_AUG_SUBSET'))

# %%
ds_full
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ds_full
#
# NameError: name 'ds_full' is not defined

# %%
indice_values = list(ds_subset['old_indices'])

# %%
len(ds_subset)
# Out:
# 2352

# %%
import torch 
org_emb_ex = torch.load(os.path.join('..', 'data', 'wikidata_embeddings', 'eva02_clip_336', 'eva02_clip_336_all_splits.pt'))

# %%
org_emb_ex.shape
# Out:
# torch.Size([20, 1024])
